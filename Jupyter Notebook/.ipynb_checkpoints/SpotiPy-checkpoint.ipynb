# %% [markdown]
# ### Import Dependencies

# %%
import json
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
from sqlalchemy import create_engine
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read the data from 1st data source

# %%
# Read the data from CSV file 
spotdf = pd.read_csv("Resources/top2018.csv")

# %%
# Create and display the dataframe
newspot_df = spotdf.drop(columns=['id','key','mode','acousticness','instrumentalness','liveness','tempo','duration_ms','time_signature'])
newspot_df = newspot_df.rename(columns={"name":"Name","artists":"Artist","danceability":"Danceability","energy":"Energy","loudness":"Loudness","speechiness":"Speechiness","valence":"Valence"})
newspot_df
# Out:
#                                                  Name               Artist  \
# 0                                          God's Plan                Drake
# 1                                                SAD!         XXXTENTACION
# 2                          rockstar (feat. 21 Savage)          Post Malone
# 3                        Psycho (feat. Ty Dolla $ign)          Post Malone
# 4                                      In My Feelings                Drake
# 5                                          Better Now          Post Malone
# 6                                           I Like It              Cardi B
# 7                            One Kiss (with Dua Lipa)        Calvin Harris
# 8                                               IDGAF             Dua Lipa
# 9                                             FRIENDS           Marshmello
# 10                                             Havana       Camila Cabello
# 11                                       Lucid Dreams           Juice WRLD
# 12                                      Nice For What                Drake
# 13                     Girls Like You (feat. Cardi B)             Maroon 5
# 14                                         The Middle                 Zedd
# 15                           All The Stars (with SZA)       Kendrick Lamar
# 16                               no tears left to cry        Ariana Grande
# 17                                                  X            Nicky Jam
# 18                                          Moonlight         XXXTENTACION
# 19                           Look Alive (feat. Drake)           BlocBoy JB
# 20  These Days (feat. Jess Glynne, Macklemore & Da...           Rudimental
# 21                                    Te Bot? - Remix           Nio Garcia
# 22                                               Mine                Bazzi
# 23                                         Youngblood  5 Seconds of Summer
# 24                                          New Rules             Dua Lipa
# 25                                       Shape of You           Ed Sheeran
# 26                           Love Lies (with Normani)               Khalid
# 27           Meant to Be (feat. Florida Georgia Line)           Bebe Rexha
# 28                                     Jocelyn Flores         XXXTENTACION
# 29                                            Perfect           Ed Sheeran
# ..                                                ...                  ...
# 70  Let Me Go (with Alesso, Florida Georgia Line &...     Hailee Steinfeld
# 71                                      Feel It Still    Portugal. The Man
# 72                  Pray For Me (with Kendrick Lamar)           The Weeknd
# 73                                    Walk It Talk It                Migos
# 74                              Him & I (with Halsey)               G-Eazy
# 75                                        Candy Paint          Post Malone
# 76                                    Congratulations          Post Malone
# 77        1, 2, 3 (feat. Jason Derulo & De La Ghetto)          Sofia Reyes
# 78                                           Criminal        Natti Natasha
# 79                                          Plug Walk         Rich The Kid
# 80                               lovely (with Khalid)        Billie Eilish
# 81                                           Stir Fry                Migos
# 82                                            HUMBLE.       Kendrick Lamar
# 83                                         Vaina Loca                Ozuna
# 84                Perfect Duet (Ed Sheeran & Beyonc?)           Ed Sheeran
# 85                      Coraz?n (feat. Nego do Borel)               Maluma
# 86                                 Young Dumb & Broke               Khalid
# 87                                   S?guelo Bailando                Ozuna
# 88                                           Downtown               Anitta
# 89                                              Bella              Wolfine
# 90                          Promises (with Sam Smith)        Calvin Harris
# 91                                         Yes Indeed             Lil Baby
# 92                                   I Like Me Better                 Lauv
# 93                                         This Is Me         Keala Settle
# 94                 Everybody Dies In Their Nightmares         XXXTENTACION
# 95                                  Rewrite The Stars            Zac Efron
# 96                  I Miss You (feat. Julia Michaels)         Clean Bandit
# 97                                         No Brainer            DJ Khaled
# 98                        Dusk Till Dawn - Radio Edit                 ZAYN
# 99                                         Be Alright           Dean Lewis
#
#     Danceability  Energy  Loudness  Speechiness  Valence
spot_df.head()
# Out:
#                      Danceability  Energy  Loudness  Speechiness  Valence
# Artist
# 5 Seconds of Summer        0.5960  0.8540   -5.1140       0.4630    0.152
# 6ix9ine                    0.9310  0.3870   -9.1270       0.4120    0.376
# Anitta                     0.7750  0.6790   -4.9850       0.1350    0.619
# Anne-Marie                 0.6970  0.6830   -2.8810       0.1170    0.603
# Ariana Grande              0.6505  0.6855   -5.7205       0.0576    0.311

# %% [markdown]
# ### Scrape the data from 2nd data source

# %%
# URL to scrape the data
links = []
artists = []
base_url = 'https://247wallst.com/special-report/2019/01/10/100-most-popular-musicians-on-tour-in-2019/'
for i in range(2, 12):
    links.append(base_url + str(i))

for url in links:
    response = requests.get(url)
    soup = bs(response.text, 'html.parser')
    
    divs = soup.find_all('div', class_='pubentry-wrapper')
    for div in divs:
        artist_info = {}
        title_span = div.find('span', class_='title-bullet')
        artists_id_name = title_span.find('strong').text
        artist_id = artists_id_name.split(".")[0]
        artist_info['artist_id'] = artist_id
        artist_name = artists_id_name.split(".")[1].strip()
        artist_info['artist_name'] = artist_name
        
        bullet_spans = div.find_all('span', class_='value-bullet')
        no_of_shows = bullet_spans[0].text.strip()
        no_of_shows = no_of_shows.split(":")[1]
        artist_info['no_of_shows'] = no_of_shows
        followers = bullet_spans[1].text.strip()
        followers = followers.split(":")[1]
        artist_info['followers'] = followers
        recent_albums = bullet_spans[2].text.strip()
        recent_albums = recent_albums.split(":")[1]
        artist_info['recent_albums'] = recent_albums
        
        artists.append(artist_info)

# %%
# Create and display the dataframe
artists_df = pd.DataFrame(artists)
artists_df.head()
# Out:
#   artist_id         artist_name followers no_of_shows  \
# 0       100             Incubus   675,465           4
# 1        99         Kodak Black   369,978           1
# 2        98               Diplo   605,749          19
# 3        97  Tyler, The Creator   647,691           2
# 4        96        Wu-Tang Clan   449,643           4
#
#                          recent_albums
# 0                             8 (2017)
# 1                 Dying to Live (2018)
# 2                       Florida (2004)
# 3                    Flower Boy (2017)
# 4   Once Upon a Time in Shaolin (2015)

# %%
# Rename the columns in the dataframe
artists_df = artists_df.rename(columns={"artist_name":"Artist","artist_id":"Artist Id","followers":"# of Followers","no_of_shows":"# of Shows","recent_albums":"Recent Album"})

# %% [markdown]
# ### Merge the two data sources

# %%
spotipy_final = pd.merge(artists_df, spot_df, how="left", on=["Artist"])

# %%
# Drop duplicates
spotipy_final = spotipy_final.dropna()

# %%
# Drop the column 'Artist Id'
spotipy_final = spotipy_final.drop(columns='Artist Id')
spotipy_final
# Out:
#              Artist # of Followers # of Shows                    Recent Album  \
# 13       Marshmello        348,373          3               Joytime II (2018)
# 32           Khalid        605,494          3            American Teen (2017)
# 35             Zedd        887,638         10              True Colors (2015)
# 42       Bebe Rexha        414,348          1             Expectations (2018)
# 59           G-Eazy        765,101          1   The Beautiful & Damned (2017)
# 62             Tyga        985,112          3                    Kyoto (2017)
# 75     Shawn Mendes        766,193         86             Shawn Mendes (2018)
# 77            Migos        737,273          4               Culture II (2018)
# 83     Travis Scott        766,831         30               Astroworld (2018)
# 91  Imagine Dragons      1,933,268          3                  Origins (2018)
# 92      Post Malone        803,006         29     Beerbongs & Bentleys (2018)
# 96          Cardi B        405,615          8      Invasion of Privacy (2018)
# 98       Bruno Mars      2,398,515          3                24K Magic (2016)
# 99    Ariana Grande      1,293,586         72                Sweetener (2018)
#
#     Danceability    Energy  Loudness  Speechiness   Valence
# 13      0.611000  0.811000 -2.742000      0.06030  0.497000
# 32      0.753000  0.593500 -5.988500      0.04350  0.366000
# 35      0.753000  0.657000 -3.061000      0.04490  0.437000
# 42      0.642000  0.772000 -6.610000      0.08480  0.589000
# 59      0.589000  0.731000 -6.343000      0.08680  0.191000
# 62      0.884000  0.559000 -7.442000      0.12000  0.342000
# 75      0.622000  0.712000 -7.321000      0.06600  0.487000
# 77      0.862000  0.722000 -5.465000      0.23500  0.452000
# 83      0.834000  0.730000 -3.714000      0.22200  0.446000
# 91      0.690500  0.801000 -4.603500      0.08590  0.477000
# 92      0.643667  0.608833 -5.913167      0.07995  0.362333
# 96      0.816000  0.726000 -3.998000      0.12900  0.650000
# 98      0.704000  0.859000 -4.877000      0.09960  0.926000
# 99      0.650500  0.685500 -5.720500      0.05760  0.311000

# %% [markdown]
# ### Connect to MySQL Database

# %%
# Create a connection to the database
rds_connection_string = "root:admin@127.0.0.1/spotipy"
engine = create_engine(f"mysql://{rds_connection_string}")

# %% [markdown]
# ### Check if the tables exist

# %%
# Display the tables in the database
engine.table_names()
# Out:
# ['artists']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
spotipy_final.to_sql(name="artists", con=engine, if_exists="append", index=False)

# %% [markdown]
# ### Confirm data has been added by querying the artists table

# %%
pd.read_sql_query('select * from artists', con=engine).head()
# Out:
#        artist # of followers # of shows                    recent album  \
# 0  Marshmello        348,373          3               Joytime II (2018)
# 1      Khalid        605,494          3            American Teen (2017)
# 2        Zedd        887,638         10              True Colors (2015)
# 3  Bebe Rexha        414,348          1             Expectations (2018)
# 4      G-Eazy        765,101          1   The Beautiful & Damned (2017)
#
#    danceability  energy  loudness  speechiness  valence
# 0         0.611  0.8110   -2.7420       0.0603    0.497
# 1         0.753  0.5935   -5.9885       0.0435    0.366
# 2         0.753  0.6570   -3.0610       0.0449    0.437
# 3         0.642  0.7720   -6.6100       0.0848    0.589
# 4         0.589  0.7310   -6.3430       0.0868    0.191

# %% [markdown]
# ### Plots of Top Touring Artists

# %%
# Make lists of all the columns
artist_list = spotipy_final['Artist'].values
followers_list = spotipy_final['# of Followers'].values
danceability_list = spotipy_final['Danceability'].values
energy_list = spotipy_final['Energy'].values
loudness_list = spotipy_final['Loudness'].values
speechiness_list = spotipy_final['Speechiness'].values
valence_list = spotipy_final['Valence'].values

# %%
# Plotting the audio features - danceability, energy, speechiness and valence
danceability_plot = plt.plot(artist_list, danceability_list, label='Danceability')
energy_plot = plt.plot(artist_list, energy_list, label='Energy')
speechiness_plot = plt.plot(artist_list, speechiness_list, label='Speechiness')
valence_plot = plt.plot(artist_list, valence_list, label='Valence')

plt.title("Audio features of Top Touring Artists")
plt.xlabel("Artists")
plt.xticks(artist_list, rotation=45)
plt.ylabel("Attribute Values")

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 10
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size

plots = danceability_plot + energy_plot + speechiness_plot + valence_plot
labels = [l.get_label() for l in plots]
plt.legend(plots, labels, loc='upper right', bbox_to_anchor=(1.5, -0.05))
plt.grid()
plt.savefig("Images/Audio features of Top Touring Artists.png")
plt.show()

# %%
# Plotting the loudness of each artist
loudness_plot = plt.plot(artist_list, loudness_list, label='Loudness')

plt.title("Loudness of Top Touring Artists")
plt.xlabel("Artists")
plt.xticks(artist_list, rotation=45)
plt.ylabel("Loudness")

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 8
fig_size[1] = 8
plt.rcParams["figure.figsize"] = fig_size

plt.grid()
plt.savefig("Images/Loudness of Top Touring Artists.png")
plt.show()
